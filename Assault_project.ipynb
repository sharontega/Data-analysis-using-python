# %%
import pandas as pd
import numpy as py
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('Assault.csv')
df.head()
# Out:
#               X             Y  OBJECTID event_unique_id Division  \
# 0 -8.847703e+06  5.416571e+06         2  GO-20141260128      D12
# 1 -8.837275e+06  5.411569e+06         3  GO-20141259483      D52
# 2 -8.840076e+06  5.413995e+06         5  GO-20141260137      D14
# 3 -8.837968e+06  5.411025e+06         6  GO-20141259767      D52
# 4 -8.837739e+06  5.411304e+06         7  GO-20141259762      D52
#
#            occurrencedate            reporteddate  \
# 0  2014/01/01 05:00:00+00  2014/01/01 05:00:00+00
# 1  2013/12/31 05:00:00+00  2014/01/01 05:00:00+00
# 2  2014/01/01 05:00:00+00  2014/01/01 05:00:00+00
# 3  2014/01/01 05:00:00+00  2014/01/01 05:00:00+00
# 4  2013/12/31 05:00:00+00  2014/01/01 05:00:00+00
#
#                                        location_type premises_type  ucr_code  \
# 0  Single Home, House (Attach Garage, Cottage, Mo...         House      1430
# 1                                   Ttc Subway Train       Transit      1430
# ...

# %%
df.columns
# Out:
# Index(['X', 'Y', 'OBJECTID', 'event_unique_id', 'Division', 'occurrencedate',
#        'reporteddate', 'location_type', 'premises_type', 'ucr_code', 'ucr_ext',
#        'offence', 'reportedyear', 'reportedmonth', 'reportedday',
#        'reporteddayofyear', 'reporteddayofweek', 'reportedhour',
#        'occurrenceyear', 'occurrencemonth', 'occurrenceday',
#        'occurrencedayofyear', 'occurrencedayofweek', 'occurrencehour',
#        'cleared', 'mci_category', 'Hood_ID', 'Neighbourhood', 'Longitude',
#        'Latitude', 'ObjectId2'],
#       dtype='object')

# %%
df.shape
# Out:
# (161833, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161833 entries, 0 to 161832
# Data columns (total 31 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   X                    161833 non-null  float64
#  1   Y                    161833 non-null  float64
#  2   OBJECTID             161833 non-null  int64
#  3   event_unique_id      161833 non-null  object
#  4   Division             161833 non-null  object
#  5   occurrencedate       161833 non-null  object
#  6   reporteddate         161833 non-null  object
#  7   location_type        161833 non-null  object
#  8   premises_type        161833 non-null  object
#  9   ucr_code             161833 non-null  int64
#  10  ucr_ext              161833 non-null  int64
#  11  offence              161833 non-null  object
#  12  reportedyear         161833 non-null  int64
#  13  reportedmonth        161833 non-null  object
#  14  reportedday          161833 non-null  int64
# ...

# %%
num=df[['X','Y','OBJECTID','ucr_code','ucr_ext','reportedyear','reportedday','reporteddayofyear','reportedhour','occurrenceyear','occurrenceday','occurrencedayofyear','occurrencehour','Longitude','Latitude','ObjectId2']]
cat=df[['cleared','offence','premises_type','Division','location_type','ucr_code','ucr_ext','occurrencemonth','occurrencedayofweek','Hood_ID','Neighbourhood']]

# %%
for i in num:
    sns.histplot(num[i])
    plt.title(i)
    plt.show()

# %%
for i in cat:
    sns.countplot(cat[i])
    plt.title(i)
    plt.show()
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
df['occurrencedate']=pd.to_datetime(df.occurrencedate)
df['reporteddate']=pd.to_datetime(df.reporteddate)

# %%
df.isnull().sum()
# Out:
# X                       0
# Y                       0
# OBJECTID                0
# event_unique_id         0
# Division                0
# occurrencedate          0
# reporteddate            0
# location_type           0
# premises_type           0
# ucr_code                0
# ucr_ext                 0
# offence                 0
# reportedyear            0
# reportedmonth           0
# reportedday             0
# reporteddayofyear       0
# reporteddayofweek       0
# reportedhour            0
# occurrenceyear         89
# occurrencemonth        89
# occurrenceday          89
# occurrencedayofyear    89
# occurrencedayofweek    89
# occurrencehour          0
# cleared                 0
# mci_category            0
# Hood_ID                 0
# Neighbourhood           0
# Longitude               0
# Latitude                0
# ObjectId2               0
# dtype: int64

# %%
df['occurrenceyear']=df['occurrenceyear'].fillna(df['occurrencedate'].dt.year)
df['occurrencemonth']=df['occurrencemonth'].fillna(df['occurrencedate'].dt.month)
df['occurrenceday']=df['occurrenceday'].fillna(df['occurrencedate'].dt.day)

# %%
df['occurrencetime']=df['occurrencedate'].dt.time
df['occurrencedate']=df['occurrencedate'].dt.date
df['reportedtime']=df['reporteddate'].dt.time
df['reporteddate']=df['reporteddate'].dt.date

# %%
df['occurrenceyear']=df.occurrenceyear.astype('int')

# %%
df['location_type']=df.location_type.apply(lambda x: x.split('(')[0].split(')')[0])

# %%
df=df.drop(['X','Y','OBJECTID','Longitude','Latitude','ObjectId2'],axis='columns')

# %%
df.head()
# Out:
#   event_unique_id Division occurrencedate reporteddate  \
# 0  GO-20141260128      D12     2014-01-01   2014-01-01
# 1  GO-20141259483      D52     2013-12-31   2014-01-01
# 2  GO-20141260137      D14     2014-01-01   2014-01-01
# 3  GO-20141259767      D52     2014-01-01   2014-01-01
# 4  GO-20141259762      D52     2013-12-31   2014-01-01
#
#                location_type premises_type  ucr_code  ucr_ext  offence  \
# 0        Single Home, House          House      1430      100  Assault
# 1           Ttc Subway Train       Transit      1430      100  Assault
# 2         Ttc Subway Station       Transit      1430      100  Assault
# 3  Streets, Roads, Highways        Outside      1430      100  Assault
# 4           Bar / Restaurant    Commercial      1430      100  Assault
#
#    reportedyear  ... occurrenceday  occurrencedayofyear  occurrencedayofweek  \
# 0          2014  ...           1.0                  1.0           Wednesday
# ...

# %%
plt.figure(figsize=(20,6))
sns.countplot(df.offence)
a=plt.xticks(rotation=90)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,6))
sns.countplot(df.premises_type)
a=plt.xticks(rotation=90)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df.cleared)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='cleared', ylabel='count'>

# %%
sns.countplot(df.occurrencetime)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='occurrencetime', ylabel='count'>

# %%
sns.kdeplot(df.reportedyear,hue=df.cleared)
# Out:
# <AxesSubplot:xlabel='reportedyear', ylabel='Density'>

# %%
plt.figure(figsize=(20,6))
sns.countplot(df.Neighbourhood[:20])
a=plt.xticks(rotation=90)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,6))
sns.countplot(df.premises_type,hue=df.cleared)
a=plt.xticks(rotation=90)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,10))
sns.countplot(df.offence,hue=df.premises_type)
a=plt.xticks(rotation=90)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
